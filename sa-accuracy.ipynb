# %%
from textblob import TextBlob
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import nltk
import pandas as pd
import re
import pandas as pd
from textblob import TextBlob
import random
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import statsmodels.api as sm # anova
from statsmodels.formula.api import ols # regression

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'<[^>]+>|https?:\/\/\S+', '', text)
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    stemmer = PorterStemmer()
    tokens = [stemmer.stem(word) for word in tokens]

    return ' '.join(tokens)

# %%
f18 = pd.read_csv('fall18-c.csv')
f19 = pd.read_csv('fall19-c.csv')
f20 = pd.read_csv('fall20-c.csv')
f21 = pd.read_csv('fall21-c.csv')
f22 = pd.read_csv('fall22-c.csv')
f23 = pd.read_csv('fall23-c.csv')
dfs = [f18, f19, f20, f21, f22, f23]
years = ['2018', '2019', '2020', '2021', '2022', '2023']

for df in dfs:
    df['content'] = df['content'].astype(str).apply(clean_text)

# %% [markdown]
# ### Year Checking

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
def get_sentiment(text):
    tb_score = TextBlob(text).sentiment.polarity
    sia_score = sia.polarity_scores(text)['compound']
    return (tb_score + sia_score) / 2

def randomize_anova_tukey(num_iterations):
    for iteration in range(num_iterations):
        # Combine and shuffle dataframes
        combined_df = pd.concat(dfs, ignore_index=True)
        shuffled_combined_df = combined_df.sample(frac=1, random_state=random.randint(1, 10000)).reset_index(drop=True)

        # Split the shuffled dataframe back into individual dataframes
        start_idx = 0
        shuffled_dfs = []
        for df in dfs:
            end_idx = start_idx + len(df)
            shuffled_df = shuffled_combined_df.iloc[start_idx:end_idx]
            shuffled_df['sentiment_score'] = shuffled_df['content'].apply(get_sentiment)
            shuffled_dfs.append(shuffled_df)
            start_idx = end_idx

        # Combine shuffled dataframes for ANOVA and Tukey HSD test
        combined_shuffled_df = pd.concat(shuffled_dfs)
        combined_shuffled_df['year'] = combined_shuffled_df.index // (len(combined_shuffled_df) // len(years))

        # Perform ANOVA
        model = ols('sentiment_score ~ C(year)', data=combined_shuffled_df).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)
        print(f"ANOVA Iteration {iteration+1}:")
        print(anova_table)

        # Perform Tukey HSD test
        tukey_results = pairwise_tukeyhsd(endog=combined_shuffled_df['sentiment_score'], 
                                          groups=combined_shuffled_df['year'], alpha=0.05)
        print(f"Tukey HSD Test Iteration {iteration+1}:")
        print(tukey_results)

# Run the function for 5 iterations
randomize_anova_tukey(5)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/naazsibia/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /var/folders/0y/pz8_1_jj35s6lqqlk697thkm0000gn/T/ipykernel_10086/2287936096.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shuffled_df['sentiment_score'] = shuffled_df['content'].apply(get_sentiment)
# ANOVA Iteration 1:
#                sum_sq       df         F    PR(>F)
# C(year)      0.608222      6.0  1.699318  0.116668
# Residual  2768.222555  46405.0       NaN       NaN
# Tukey HSD Test Iteration 1:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      0      1  -0.0037 0.9648 -0.0153 0.0079  False
#      0      2  -0.0024 0.9962  -0.014 0.0091  False
#      0      3   0.0022  0.998 -0.0094 0.0137  False
#      0      4   0.0055 0.7975  -0.006 0.0171  False
#      0      5  -0.0024 0.9967  -0.014 0.0092  False
#      0      6    0.264 0.7277 -0.2453 0.7733  False
#      1      2   0.0013 0.9999 -0.0103 0.0129  False
#      1      3   0.0059 0.7462 -0.0057 0.0175  False
#      1      4   0.0093 0.2179 -0.0023 0.0208  False
#      1      5   0.0013 0.9999 -0.0102 0.0129  False
#      1      6   0.2677 0.7143 -0.2415  0.777  False
#      2      3   0.0046 0.9047  -0.007 0.0162  False
#      2      4    0.008 0.3958 -0.0036 0.0196  False
#      2      5   0.0001    1.0 -0.0115 0.0116  False
#      2      6   0.2665 0.7189 -0.2428 0.7757  False
#      3      4   0.0034 0.9786 -0.0082 0.0149  False
#      3      5  -0.0045 0.9103 -0.0161  0.007  False
#      3      6   0.2618 0.7353 -0.2474 0.7711  False
#      4      5  -0.0079 0.4058 -0.0195 0.0037  False
#      4      6   0.2585 0.7471 -0.2508 0.7678  False
#      5      6   0.2664 0.7191 -0.2429 0.7757  False
# ---------------------------------------------------
# /var/folders/0y/pz8_1_jj35s6lqqlk697thkm0000gn/T/ipykernel_10086/2287936096.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shuffled_df['sentiment_score'] = shuffled_df['content'].apply(get_sentiment)
# ANOVA Iteration 2:
#                sum_sq       df         F    PR(>F)
# C(year)      0.395982      6.0  1.106253  0.355692
# Residual  2768.434795  46405.0       NaN       NaN
# Tukey HSD Test Iteration 2:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      0      1   -0.004 0.9481 -0.0156 0.0075  False
#      0      2   0.0044 0.9215 -0.0072  0.016  False
#      0      3   0.0011    1.0 -0.0105 0.0126  False
#      0      4   0.0017 0.9995 -0.0099 0.0133  False
#      0      5  -0.0034 0.9785  -0.015 0.0082  False
#      0      6   0.0229    1.0 -0.4864 0.5322  False
#      1      2   0.0084 0.3243 -0.0031   0.02  False
#      1      3   0.0051 0.8531 -0.0065 0.0167  False
#      1      4   0.0057 0.7687 -0.0058 0.0173  False
#      1      5   0.0007    1.0 -0.0109 0.0122  False
#      1      6   0.0269    1.0 -0.4824 0.5362  False
#      2      3  -0.0033 0.9795 -0.0149 0.0082  False
#      2      4  -0.0027 0.9933 -0.0143 0.0089  False
#      2      5  -0.0078 0.4273 -0.0194 0.0038  False
#      2      6   0.0185    1.0 -0.4908 0.5278  False
#      3      4   0.0006    1.0 -0.0109 0.0122  False
#      3      5  -0.0044  0.919  -0.016 0.0071  False
#      3      6   0.0218    1.0 -0.4875 0.5311  False
#      4      5  -0.0051 0.8561 -0.0167 0.0065  False
#      4      6   0.0212    1.0 -0.4881 0.5305  False
#      5      6   0.0263    1.0  -0.483 0.5356  False
# ---------------------------------------------------
# /var/folders/0y/pz8_1_jj35s6lqqlk697thkm0000gn/T/ipykernel_10086/2287936096.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shuffled_df['sentiment_score'] = shuffled_df['content'].apply(get_sentiment)
# ANOVA Iteration 3:
#                sum_sq       df         F    PR(>F)
# C(year)      0.371633      6.0  1.038222  0.398013
# Residual  2768.459144  46405.0       NaN       NaN
# Tukey HSD Test Iteration 3:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      0      1   0.0049 0.8775 -0.0067 0.0165  False
#      0      2   0.0072 0.5218 -0.0044 0.0188  False
#      0      3   0.0004    1.0 -0.0111  0.012  False
#      0      4   0.0025 0.9955 -0.0091 0.0141  False
#      0      5   0.0045 0.9134 -0.0071 0.0161  False
#      0      6   0.1901 0.9281 -0.3192 0.6994  False
#      1      2   0.0023  0.997 -0.0092 0.0139  False
#      1      3  -0.0044 0.9186  -0.016 0.0071  False
#      1      4  -0.0024 0.9968 -0.0139 0.0092  False
#      1      5  -0.0004    1.0  -0.012 0.0112  False
#      1      6   0.1852 0.9362 -0.3241 0.6945  False
#      2      3  -0.0068 0.5976 -0.0184 0.0048  False
#      2      4  -0.0047 0.8951 -0.0163 0.0069  False
#      2      5  -0.0027 0.9931 -0.0143 0.0089  False
#      2      6   0.1829 0.9399 -0.3264 0.6922  False
#      3      4   0.0021 0.9984 -0.0095 0.0137  False
#      3      5   0.0041 0.9458 -0.0075 0.0156  False
#      3      6   0.1897 0.9289 -0.3196  0.699  False
#      4      5    0.002 0.9988 -0.0096 0.0136  False
#      4      6   0.1876 0.9324 -0.3217 0.6969  False
#      5      6   0.1856 0.9356 -0.3237 0.6949  False
# ---------------------------------------------------
# /var/folders/0y/pz8_1_jj35s6lqqlk697thkm0000gn/T/ipykernel_10086/2287936096.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shuffled_df['sentiment_score'] = shuffled_df['content'].apply(get_sentiment)
# ANOVA Iteration 4:
#                sum_sq       df         F    PR(>F)
# C(year)      0.524417      6.0  1.465131  0.185718
# Residual  2768.306360  46405.0       NaN       NaN
# Tukey HSD Test Iteration 4:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      0      1  -0.0046 0.9071 -0.0162  0.007  False
#      0      2   0.0027 0.9939 -0.0089 0.0142  False
#      0      3   0.0014 0.9998 -0.0102  0.013  False
#      0      4  -0.0061 0.7114 -0.0177 0.0055  False
#      0      5   -0.003 0.9884 -0.0146 0.0086  False
#      0      6  -0.1657 0.9625  -0.675 0.3436  False
#      1      2   0.0072 0.5193 -0.0043 0.0188  False
#      1      3    0.006 0.7309 -0.0056 0.0176  False
#      1      4  -0.0015 0.9997 -0.0131 0.0101  False
#      1      5   0.0016 0.9997   -0.01 0.0132  False
#      1      6  -0.1611 0.9673 -0.6704 0.3482  False
#      2      3  -0.0013 0.9999 -0.0128 0.0103  False
#      2      4  -0.0088 0.2785 -0.0203 0.0028  False
#      2      5  -0.0057 0.7804 -0.0172 0.0059  False
#      2      6  -0.1684 0.9595 -0.6776 0.3409  False
#      3      4  -0.0075 0.4718 -0.0191 0.0041  False
#      3      5  -0.0044 0.9221  -0.016 0.0072  False
#      3      6  -0.1671 0.9609 -0.6764 0.3422  False
#      4      5   0.0031 0.9858 -0.0085 0.0147  False
#      4      6  -0.1596 0.9689 -0.6689 0.3497  False
#      5      6  -0.1627 0.9657  -0.672 0.3466  False
# ---------------------------------------------------
# /var/folders/0y/pz8_1_jj35s6lqqlk697thkm0000gn/T/ipykernel_10086/2287936096.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shuffled_df['sentiment_score'] = shuffled_df['content'].apply(get_sentiment)
# ANOVA Iteration 5:
#                sum_sq       df         F    PR(>F)
# C(year)      0.560429      6.0  1.565763  0.152601
# Residual  2768.270348  46405.0       NaN       NaN
# Tukey HSD Test Iteration 5:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      0      1  -0.0091 0.2354 -0.0207 0.0025  False
#      0      2  -0.0008    1.0 -0.0124 0.0108  False
#      0      3  -0.0017 0.9996 -0.0132 0.0099  False
#      0      4   0.0009    1.0 -0.0106 0.0125  False
#      0      5  -0.0036 0.9692 -0.0152  0.008  False
#      0      6  -0.1539  0.974 -0.6632 0.3554  False
#      1      2   0.0083 0.3406 -0.0033 0.0199  False
#      1      3   0.0074 0.4847 -0.0041  0.019  False
#      1      4     0.01 0.1392 -0.0015 0.0216  False
#      1      5   0.0055 0.8045 -0.0061 0.0171  False
#      1      6  -0.1448  0.981 -0.6541 0.3645  False
#      2      3  -0.0009    1.0 -0.0125 0.0107  False
#      2      4   0.0017 0.9995 -0.0099 0.0133  False
#      2      5  -0.0028 0.9911 -0.0144 0.0087  False
#      2      6  -0.1531 0.9747 -0.6624 0.3562  False
#      3      4   0.0026 0.9945  -0.009 0.0142  False
#      3      5   -0.002 0.9989 -0.0135 0.0096  False
#      3      6  -0.1522 0.9754 -0.6615 0.3571  False
#      4      5  -0.0046 0.9082 -0.0161  0.007  False
#      4      6  -0.1548 0.9732 -0.6641 0.3545  False
#      5      6  -0.1503  0.977 -0.6595  0.359  False
# ---------------------------------------------------

# %% [markdown]
# ### Week Checking

# %%
from datetime import datetime
start_dates = {
    '2018': datetime(2018, 9, 1),
    '2019': datetime(2019, 9, 1),
    '2020': datetime(2020, 9, 1),
    '2021': datetime(2021, 9, 1),
    '2022': datetime(2022, 9, 1),
    '2023': datetime(2023, 9, 1)
}

for year, df in zip(years, dfs):
    # Ensure 'created_at' is converted to datetime and is timezone-naive
    df['created'] = pd.to_datetime(df['created']).dt.tz_localize(None)
    
    # Calculate the course week number
    df['week'] = ((df['created'] - start_dates[year]).dt.days // 7) + 1
    
    # Filter out data that is outside the 1-12 week range
    df = df[(df['week'] >= 1) & (df['week'] <= 12)]

for df in dfs:
    df['sentiment_score'] = df['content'].apply(get_sentiment)

# %%
import pandas as pd
import random
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import seaborn as sns
import matplotlib.pyplot as plt

# Number of iterations for random shuffling
num_iterations = 5

for iteration in range(num_iterations):
    print(f"Iteration {iteration + 1}")

    shuffled_dfs = []
    for df in dfs:
        # Shuffle only the sentiment scores within the dataframe
        shuffled_scores = random.sample(list(df['sentiment_score']), len(df['sentiment_score']))
        shuffled_df = df.copy()
        shuffled_df['sentiment_score'] = shuffled_scores
        shuffled_dfs.append(shuffled_df)

    # Concatenate the shuffled dataframes for ANOVA and Tukey HSD
    all_data = pd.concat(shuffled_dfs)
    all_data['year'] = all_data.index // len(all_data) // len(dfs[0])

    # One-Way ANOVA
    model = ols('sentiment_score ~ C(week)', data=all_data).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    print("ANOVA Results:")
    print(anova_table)

    # Tukey HSD
    tukey_results = pairwise_tukeyhsd(endog=all_data['sentiment_score'], groups=all_data['week'], alpha=0.05)
    print("Tukey HSD Results:")
    print(tukey_results)

    # Regression Analysis
    for year, df in zip(years, shuffled_dfs):
        # OLS Regression
        model = sm.OLS(df['sentiment_score'], sm.add_constant(df['week'])).fit()
        print(f"OLS Regression Results for {year}:")
        print(model.summary())
# Out:
# Iteration 1
# ANOVA Results:
#                sum_sq       df         F    PR(>F)
# C(week)      2.282965     19.0  2.014887  0.005476
# Residual  2766.547812  46392.0       NaN       NaN
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/integrate/quadpack.py:879: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Tukey HSD Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     10     13  -0.0019    1.0 -0.0223  0.0185  False
#     10     14   0.0114 0.8926 -0.0086  0.0314  False
#     10     15   0.0228 0.4764 -0.0078  0.0533  False
#     10     16   0.0036    1.0 -0.0216  0.0288  False
#     10     17  -0.0101    1.0  -0.087  0.0668  False
#     10     18    0.017    1.0 -0.1502  0.1841  False
#     11     12   0.0125 0.4942 -0.0044  0.0294  False
#     11     13  -0.0071 0.9987 -0.0256  0.0114  False
#     11     14   0.0063 0.9997 -0.0118  0.0244  False
#     11     15   0.0176 0.8458 -0.0118   0.047  False
#     11     16  -0.0016    1.0 -0.0253  0.0222  False
#     11     17  -0.0153    1.0 -0.0917  0.0612  False
#     11     18   0.0118    1.0 -0.1551  0.1787  False
#     12     13  -0.0196 0.0462  -0.039 -0.0001   True
#     12     14  -0.0062 0.9999 -0.0253  0.0128  False
#     12     15   0.0051    1.0 -0.0249  0.0351  False
#     12     16  -0.0141 0.8875 -0.0385  0.0104  False
#     12     17  -0.0278 0.9994 -0.1044  0.0489  False
#     12     18  -0.0007    1.0 -0.1677  0.1663  False
#     13     14   0.0133  0.726 -0.0071  0.0338  False
#     13     15   0.0247 0.3343 -0.0062  0.0556  False
#     13     16   0.0055    1.0 -0.0201  0.0311  False
#     13     17  -0.0082    1.0 -0.0852  0.0689  False
#     13     18   0.0189    1.0 -0.1483  0.1861  False
#     14     15   0.0113 0.9992 -0.0193  0.0419  False
#     14     16  -0.0078 0.9999 -0.0331  0.0174  False
#     14     17  -0.0215    1.0 -0.0985  0.0554  False
#     14     18   0.0055    1.0 -0.1616  0.1727  False
#     15     16  -0.0191 0.9106 -0.0534  0.0151  False
#     15     17  -0.0328 0.9968 -0.1132  0.0475  False
#     15     18  -0.0058    1.0 -0.1746   0.163  False
#     16     17  -0.0137    1.0 -0.0922  0.0648  False
#     16     18   0.0133    1.0 -0.1545  0.1812  False
#     17     18    0.027    1.0 -0.1559    0.21  False
# ----------------------------------------------------
# OLS Regression Results for 2018:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.5376
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.463
# Time:                        00:03:57   Log-Likelihood:                 98.549
# No. Observations:                3942   AIC:                            -193.1
# Df Residuals:                    3940   BIC:                            -180.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1057      0.011      9.824      0.000       0.085       0.127
# week          -0.0007      0.001     -0.733      0.463      -0.003       0.001
# ==============================================================================
# Omnibus:                      128.770   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.457
# Skew:                           0.350   Prob(JB):                     7.94e-39
# Kurtosis:                       3.761   Cond. No.                         31.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2019:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.5797
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.446
# Time:                        00:03:57   Log-Likelihood:                 322.74
# No. Observations:                7153   AIC:                            -641.5
# Df Residuals:                    7151   BIC:                            -627.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0578      0.007      7.793      0.000       0.043       0.072
# week           0.0005      0.001      0.761      0.446      -0.001       0.002
# ==============================================================================
# Omnibus:                      147.810   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              286.400
# Skew:                           0.123   Prob(JB):                     6.44e-63
# Kurtosis:                       3.949   Cond. No.                         29.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2020:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                   0.03612
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.849
# Time:                        00:03:57   Log-Likelihood:                -194.77
# No. Observations:               10751   AIC:                             393.5
# Df Residuals:                   10749   BIC:                             408.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0688      0.006     11.018      0.000       0.057       0.081
# week          -0.0001      0.001     -0.190      0.849      -0.002       0.001
# ==============================================================================
# Omnibus:                      117.448   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              163.465
# Skew:                           0.143   Prob(JB):                     3.19e-36
# Kurtosis:                       3.533   Cond. No.                         22.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2021:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.1334
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.715
# Time:                        00:03:57   Log-Likelihood:                -595.20
# No. Observations:                8728   AIC:                             1194.
# Df Residuals:                    8726   BIC:                             1209.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0829      0.006     13.832      0.000       0.071       0.095
# week           0.0002      0.001      0.365      0.715      -0.001       0.001
# ==============================================================================
# Omnibus:                       99.865   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              157.956
# Skew:                           0.097   Prob(JB):                     5.02e-35
# Kurtosis:                       3.630   Cond. No.                         22.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2022:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.562
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.211
# Time:                        00:03:57   Log-Likelihood:                 312.28
# No. Observations:                7180   AIC:                            -620.6
# Df Residuals:                    7178   BIC:                            -606.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1086      0.008     12.937      0.000       0.092       0.125
# week          -0.0010      0.001     -1.250      0.211      -0.002       0.001
# ==============================================================================
# Omnibus:                      175.886   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              313.145
# Skew:                           0.199   Prob(JB):                     1.00e-68
# Kurtosis:                       3.942   Cond. No.                         33.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2023:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                  0.005189
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.943
# Time:                        00:03:57   Log-Likelihood:                -214.95
# No. Observations:                8658   AIC:                             433.9
# Df Residuals:                    8656   BIC:                             448.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0615      0.007      9.187      0.000       0.048       0.075
# week        5.437e-05      0.001      0.072      0.943      -0.001       0.002
# ==============================================================================
# Omnibus:                      116.851   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              212.907
# Skew:                           0.038   Prob(JB):                     5.86e-47
# Kurtosis:                       3.764   Cond. No.                         22.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Iteration 2
# ANOVA Results:
#                sum_sq       df         F    PR(>F)
# C(week)      2.099488     19.0  1.852831  0.013223
# Residual  2766.731289  46392.0       NaN       NaN
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/integrate/quadpack.py:879: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Tukey HSD Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#     -1      0  -0.0491 0.9999 -0.2089 0.1107  False
#     -1      1  -0.0481 0.9999 -0.1951 0.0989  False
#     -1      2   -0.032    1.0 -0.1704 0.1064  False
#     -1      3  -0.0324    1.0 -0.1707 0.1058  False
#     -1      4  -0.0348    1.0 -0.1727 0.1031  False
#     -1      5  -0.0325    1.0 -0.1699 0.1049  False
#     -1      6   -0.034    1.0 -0.1715 0.1035  False
#     -1      7  -0.0341    1.0 -0.1726 0.1043  False
#     -1      8  -0.0412    1.0 -0.1796 0.0973  False
#     -1      9  -0.0361    1.0  -0.174 0.1018  False
#     -1     10  -0.0375    1.0 -0.1751 0.1001  False
#     -1     11  -0.0246    1.0 -0.1619 0.1128  False
#     -1     12  -0.0274    1.0 -0.1648 0.1101  False
#     -1     13  -0.0282    1.0 -0.1659 0.1094  False
#     -1     14  -0.0263    1.0 -0.1639 0.1112  False
#     -1     15  -0.0078    1.0 -0.1474 0.1317  False
#     -1     16  -0.0217    1.0 -0.1602 0.1167  False
#     -1     17  -0.0263    1.0 -0.1827   0.13  False
#     -1     18   0.0807  0.999 -0.1349 0.2963  False
#      0      1    0.001    1.0 -0.0975 0.0995  False
#      0      2   0.0171    1.0  -0.068 0.1023  False
#     14     15   0.0185 0.8354 -0.0121 0.0491  False
#     14     16   0.0046    1.0 -0.0206 0.0299  False
#     14     17      0.0    1.0 -0.0769  0.077  False
#     14     18   0.1071 0.7558 -0.0601 0.2742  False
#     15     16  -0.0139 0.9972 -0.0481 0.0204  False
#     15     17  -0.0185    1.0 -0.0988 0.0619  False
#     15     18   0.0886 0.9492 -0.0802 0.2573  False
#     16     17  -0.0046    1.0  -0.083 0.0739  False
#     16     18   0.1024 0.8234 -0.0654 0.2703  False
#     17     18    0.107 0.8707 -0.0759 0.2899  False
# ---------------------------------------------------
# OLS Regression Results for 2018:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.852
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.174
# Time:                        00:04:02   Log-Likelihood:                 99.206
# No. Observations:                3942   AIC:                            -194.4
# Df Residuals:                    3940   BIC:                            -181.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0846      0.011      7.863      0.000       0.064       0.106
# week           0.0013      0.001      1.361      0.174      -0.001       0.003
# ==============================================================================
# Omnibus:                      129.215   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.636
# Skew:                           0.350   Prob(JB):                     4.40e-39
# Kurtosis:                       3.766   Cond. No.                         31.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2019:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                 0.0003618
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.985
# Time:                        00:04:02   Log-Likelihood:                 322.45
# No. Observations:                7153   AIC:                            -640.9
# Df Residuals:                    7151   BIC:                            -627.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0632      0.007      8.519      0.000       0.049       0.078
# week       -1.289e-05      0.001     -0.019      0.985      -0.001       0.001
# ==============================================================================
# Omnibus:                      147.980   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              287.090
# Skew:                           0.122   Prob(JB):                     4.56e-63
# Kurtosis:                       3.950   Cond. No.                         29.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2020:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.454
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.228
# Time:                        00:04:02   Log-Likelihood:                -194.06
# No. Observations:               10751   AIC:                             392.1
# Df Residuals:                   10749   BIC:                             406.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0607      0.006      9.728      0.000       0.048       0.073
# week           0.0009      0.001      1.206      0.228      -0.001       0.002
# ==============================================================================
# Omnibus:                      117.288   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              163.003
# Skew:                           0.143   Prob(JB):                     4.02e-36
# Kurtosis:                       3.531   Cond. No.                         22.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2021:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4922
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.483
# Time:                        00:04:02   Log-Likelihood:                -595.02
# No. Observations:                8728   AIC:                             1194.
# Df Residuals:                    8726   BIC:                             1208.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0811      0.006     13.534      0.000       0.069       0.093
# week           0.0004      0.001      0.702      0.483      -0.001       0.002
# ==============================================================================
# Omnibus:                      100.060   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.271
# Skew:                           0.097   Prob(JB):                     4.28e-35
# Kurtosis:                       3.630   Cond. No.                         22.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2022:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4350
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.510
# Time:                        00:04:02   Log-Likelihood:                 311.72
# No. Observations:                7180   AIC:                            -619.4
# Df Residuals:                    7178   BIC:                            -605.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0934      0.008     11.131      0.000       0.077       0.110
# week           0.0005      0.001      0.660      0.510      -0.001       0.002
# ==============================================================================
# Omnibus:                      176.335   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              314.157
# Skew:                           0.200   Prob(JB):                     6.05e-69
# Kurtosis:                       3.944   Cond. No.                         33.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2023:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.1407
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.708
# Time:                        00:04:02   Log-Likelihood:                -214.88
# No. Observations:                8658   AIC:                             433.8
# Df Residuals:                    8656   BIC:                             447.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0596      0.007      8.909      0.000       0.047       0.073
# week           0.0003      0.001      0.375      0.708      -0.001       0.002
# ==============================================================================
# Omnibus:                      116.826   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              212.887
# Skew:                           0.038   Prob(JB):                     5.92e-47
# Kurtosis:                       3.764   Cond. No.                         22.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Iteration 3
# ANOVA Results:
#                sum_sq       df         F    PR(>F)
# C(week)      2.590392     19.0  2.286468  0.001132
# Residual  2766.240385  46392.0       NaN       NaN
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/integrate/quadpack.py:879: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# Tukey HSD Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#     -1      0   0.0592 0.9991 -0.1006  0.2189  False
#     -1      1   0.0419    1.0 -0.1051   0.189  False
#     -1      2   0.0541 0.9982 -0.0843  0.1925  False
#     -1      3   0.0386    1.0 -0.0996  0.1769  False
#     -1      4   0.0389    1.0  -0.099  0.1768  False
#     -1      5   0.0412    1.0 -0.0961  0.1786  False
#     -1      6   0.0355    1.0 -0.1019   0.173  False
#     -1      7   0.0449 0.9999 -0.0936  0.1833  False
#     -1      8   0.0456 0.9998 -0.0928  0.1841  False
#     -1      9    0.053 0.9986 -0.0849  0.1909  False
#     -1     10   0.0307    1.0 -0.1069  0.1683  False
#     -1     11   0.0469 0.9997 -0.0904  0.1842  False
#     -1     12   0.0502 0.9993 -0.0873  0.1876  False
#     -1     13   0.0479 0.9996 -0.0897  0.1856  False
#     -1     14   0.0509 0.9991 -0.0867  0.1885  False
#     -1     15   0.0642  0.987 -0.0753  0.2037  False
#     -1     16   0.0463 0.9998 -0.0921  0.1848  False
#     -1     17   0.0508 0.9999 -0.1055  0.2072  False
#     -1     18    0.104 0.9781 -0.1116  0.3195  False
#      0      1  -0.0172    1.0 -0.1157  0.0813  False
#      0      2  -0.0051    1.0 -0.0902    0.08  False
#      0      3  -0.0205    1.0 -0.1054  0.0644  False
#      0      4  -0.0203    1.0 -0.1045   0.064  False
#      0      5  -0.0179    1.0 -0.1013  0.0655  False
#      0      6  -0.0236    1.0 -0.1072  0.0599  False
#      0      7  -0.0143    1.0 -0.0994  0.0709  False
#      0      8  -0.0135    1.0 -0.0986  0.0716  False
#      0      9  -0.0062    1.0 -0.0905  0.0781  False
#      0     10  -0.0285 0.9997 -0.1122  0.0553  False
#      0     11  -0.0123    1.0 -0.0956   0.071  False
#      0     12   -0.009    1.0 -0.0925  0.0745  False
#      0     13  -0.0112    1.0  -0.095  0.0726  False
#      0     14  -0.0082    1.0  -0.092  0.0755  False
#      0     15    0.005    1.0 -0.0818  0.0919  False
#      0     16  -0.0128    1.0 -0.0979  0.0723  False
#      0     17  -0.0083    1.0 -0.1202  0.1036  False
#      0     18   0.0448    1.0  -0.141  0.2307  False
#      1      2   0.0121    1.0 -0.0456  0.0698  False
#      1      3  -0.0033    1.0 -0.0607  0.0541  False
#      1      4  -0.0031    1.0 -0.0594  0.0533  False
#      1      5  -0.0007    1.0 -0.0558  0.0544  False
#      1      6  -0.0064    1.0 -0.0618  0.0489  False
#      1      7   0.0029    1.0 -0.0548  0.0607  False
#      1      8   0.0037    1.0  -0.054  0.0614  False
#      1      9    0.011    1.0 -0.0454  0.0675  False

#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.3579
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.550
# Time:                        00:04:14   Log-Likelihood:                 98.459
# No. Observations:                3942   AIC:                            -192.9
# Df Residuals:                    3940   BIC:                            -180.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1044      0.011      9.697      0.000       0.083       0.125
# week          -0.0006      0.001     -0.598      0.550      -0.003       0.001
# ==============================================================================
# Omnibus:                      128.786   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.574
# Skew:                           0.350   Prob(JB):                     7.49e-39
# Kurtosis:                       3.762   Cond. No.                         31.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2019:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.1915
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.662
# Time:                        00:04:14   Log-Likelihood:                 322.55
# No. Observations:                7153   AIC:                            -641.1
# Df Residuals:                    7151   BIC:                            -627.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0661      0.007      8.908      0.000       0.052       0.081
# week          -0.0003      0.001     -0.438      0.662      -0.002       0.001
# ==============================================================================
# Omnibus:                      147.931   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              286.851
# Skew:                           0.123   Prob(JB):                     5.14e-63
# Kurtosis:                       3.950   Cond. No.                         29.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2020:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.7420
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.389
# Time:                        00:04:14   Log-Likelihood:                -194.42
# No. Observations:               10751   AIC:                             392.8
# Df Residuals:                   10749   BIC:                             407.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0726      0.006     11.640      0.000       0.060       0.085
# week          -0.0006      0.001     -0.861      0.389      -0.002       0.001
# ==============================================================================
# Omnibus:                      117.634   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              163.861
# Skew:                           0.142   Prob(JB):                     2.62e-36
# Kurtosis:                       3.534   Cond. No.                         22.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2021:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.6775
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.410
# Time:                        00:04:14   Log-Likelihood:                -594.92
# No. Observations:                8728   AIC:                             1194.
# Df Residuals:                    8726   BIC:                             1208.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0804      0.006     13.426      0.000       0.069       0.092
# week           0.0005      0.001      0.823      0.410      -0.001       0.002
# ==============================================================================
# Omnibus:                      100.241   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.610
# Skew:                           0.097   Prob(JB):                     3.62e-35
# Kurtosis:                       3.631   Cond. No.                         22.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2022:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.620
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.203
# Time:                        00:04:14   Log-Likelihood:                 312.31
# No. Observations:                7180   AIC:                            -620.6
# Df Residuals:                    7178   BIC:                            -606.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0886      0.008     10.552      0.000       0.072       0.105
# week           0.0010      0.001      1.273      0.203      -0.001       0.003
# ==============================================================================
# Omnibus:                      175.037   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              311.976
# Skew:                           0.198   Prob(JB):                     1.80e-68
# Kurtosis:                       3.941   Cond. No.                         33.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS Regression Results for 2023:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        sentiment_score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     2.202
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):              0.138
# Time:                        00:04:14   Log-Likelihood:                -213.85
# No. Observations:                8658   AIC:                             431.7
# Df Residuals:                    8656   BIC:                             445.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0528      0.007      7.893      0.000       0.040       0.066
# week           0.0011      0.001      1.484      0.138      -0.000       0.003
# ==============================================================================
# Omnibus:                      116.763   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              212.682
# Skew:                           0.038   Prob(JB):                     6.56e-47
# Kurtosis:                       3.764   Cond. No.                         22.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
